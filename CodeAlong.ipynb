# %% [markdown]
# # GreenDatathon: Mapping Forest Futures
#
# ## Introduction and Event Overview
#
# Welcome to the GreenDatathon: Mapping Forest Futures! This 3-hour data analysis challenge focuses on global forest trends from 1990 to 2020. Our goal is to introduce you to data manipulation and basic programming skills using real-world environmental data.

# %% [markdown]
# # Importing necessary libraries

# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import plotly
from sklearn.linear_model import LinearRegression
#TO-DO

# %% [markdown]
# # 1. Loading the data

# %%
# Load the dataset 'Forest_Area.csv' into a DataFrame named 'df'
# This step involves reading the CSV file using pandas and storing its contents in a variable called 'df'

df = pd.read_csv('Forest_Area.csv')

# OR uncomment and run the below two cells to upload the data (do only one!)
# from google.colab import files
# uploaded = files.upload()

# %% [markdown]
# # 2. Basic data exploration

# %%
df.head()
# Out:
#    CountryID Country and Area  Forest Area, 1990  Forest Area, 2000  \
# 0        NaN            WORLD         4236433.42         4158049.52
# 1        4.0      Afghanistan            1208.44            1208.44
# 2        8.0          Albania             788.80             769.30
# 3       12.0          Algeria            1667.00            1579.00
# 4       16.0   American Samoa              18.07              17.73
#
#    Forest Area, 2010 Forest Area, 2015  Forest Area, 2020  \
# 0         4106316.94
#          4058930.81
# 1            1208.44           1208.44            1208.44
# 2             782.07            789.19             788.90
# 3            1918.00              1956            1949.00
# 4              17.43             17.28              17.13
#
#    Total Land Area, 2020  \
# 0             13003000.0
# 1                65286.0
# 2                 2740.0
# 3               238174.0
# 4                   20.0
#
#    Forest Area as a Proportion of Total Land Area, 2020  \
# 0                                              31.13
# 1                                               1.85
# 2                                              28.79
# 3                                               0.82
# 4                                              85.65
#
#   Deforestation, 2015-2020 Total Forest Area Affected by Fire, 2015
# 0                    10200                                    98040
# 1                      ...                                      ...
# 2                      ...                                      ...
# 3                      5.4                                      ...
# 4                      ...                                        0

# %%
# Print the first 10 rows of the DataFrame to get an overview of the data
df.head(10)
# Out:
#    CountryID     Country and Area  Forest Area, 1990  Forest Area, 2000  \
# 0        NaN                WORLD         4236433.42         4158049.52
# 1        4.0          Afghanistan            1208.44            1208.44
# 2        8.0              Albania             788.80             769.30
# 3       12.0              Algeria            1667.00            1579.00
# 4       16.0       American Samoa              18.07              17.73
# 5       20.0              Andorra              16.00              16.00
# 6       24.0               Angola           79262.78           77708.61
# 7      660.0             Anguilla               5.50               5.50
# 8       28.0  Antigua and Barbuda              10.11               9.45
# 9       32.0            Argentina           35204.00           33378.00
#
#    Forest Area, 2010 Forest Area, 2015  Forest Area, 2020  \
# 0         4106316.94
#          4058930.81
# 1            1208.44           1208.44            1208.44
# 2             782.07            789.19             788.90
# 3            1918.00              1956            1949.00
# 4              17.43             17.28              17.13
# 5              16.00                16              16.00
# 6           72158.00          69382.69           66607.38
# 7               5.50               5.5               5.50
# 8               8.78              8.45               8.12
# 9           30214.00             29097           28573.00
#
#    Total Land Area, 2020  \
# 0             13003000.0
# 1                65286.0
# 2                 2740.0
# 3               238174.0
# 4                   20.0
# 5                   47.0
# 6               124670.0
# 7                    9.0
# 8                   44.0
# 9               273669.0
#
#    Forest Area as a Proportion of Total Land Area, 2020  \
# 0                                              31.13
# 1                                               1.85
# 2                                              28.79
# 3                                               0.82
# 4                                              85.65
# 5                                              34.04
# 6                                              53.43
# 7                                              61.11
# 8                                              18.45
# 9                                              10.44
#
#   Deforestation, 2015-2020 Total Forest Area Affected by Fire, 2015
# 0                    10200                                    98040
# 1                      ...                                      ...
# 2                      ...                                      ...
# 3                      5.4                                      ...
# 4                      ...                                        0
# 5                      ...                                      ...
# 6                      ...                                      ...
# 7                      ...                                      ...
# 8                      ...                                      ...
# 9                    134.8                                      128

# %%
# @title Forest Area, 2010

from matplotlib import pyplot as plt
df['Forest Area, 2010'].plot(kind='line', figsize=(8, 4), title='Forest Area, 2010')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Print the last 5 rows of the DataFrame to get an overview of the data
df.tail()
# Out:
#      CountryID Country and Area  Forest Area, 1990  Forest Area, 2000  \
# 234      887.0            Yemen             549.00             549.00
# 235      894.0           Zambia           47412.00           47054.00
# 236      716.0         Zimbabwe           18826.68           18365.98
# 237        NaN              NaN                NaN                NaN
# 238        NaN              NaN                NaN                NaN
#
#      Forest Area, 2010 Forest Area, 2015  Forest Area, 2020  \
# 234             549.00               549             549.00
# 235           46696.00           45755.1           44814.03
# 236           17905.28          17674.93           17444.58
# 237                NaN               NaN                NaN
# 238                NaN               NaN                NaN
#
#      Total Land Area, 2020  \
# 234                52797.0
# 235                74339.0
# 236                38685.0
# 237                    NaN
# 238                    NaN
#
#      Forest Area as a Proportion of Total Land Area, 2020  \
# 234                                               1.04
# 235                                              60.28
# 236                                              45.09
# 237                                                NaN
# 238                                                NaN
#
#     Deforestation, 2015-2020 Total Forest Area Affected by Fire, 2015
# 234                      ...                                      ...
# 235                   189.71                                    15077
# 236                    46.07                                     2830
# 237                      NaN                                      NaN
# 238                      NaN                                      NaN

# %%
# Print the last 10 rows of the DataFrame to get an overview of the data
df.tail(10)
# Out:
#      CountryID                    Country and Area  Forest Area, 1990  \
# 229      548.0                             Vanuatu             442.30
# 230      862.0  Venezuela (Bolivarian Republic of)           52026.00
# 231      704.0                            Viet Nam            9375.96
# 232      876.0           Wallis and Futuna Islands               5.80
# 233      732.0                      Western Sahara             665.10
# 234      887.0                               Yemen             549.00
# 235      894.0                              Zambia           47412.00
# 236      716.0                            Zimbabwe           18826.68
# 237        NaN                                 NaN                NaN
# 238        NaN                                 NaN                NaN
#
#      Forest Area, 2000  Forest Area, 2010 Forest Area, 2015  \
# 229             442.30             442.30             442.3
# 230           49151.00           47505.00             46683
# 231           11784.10           13388.06          14061.86
# 232               5.81               5.82              5.83
# 233             669.31             665.11             664.7
# 234             549.00             549.00               549
# 235           47054.00           46696.00           45755.1
# 236           18365.98           17905.28          17674.93
# 237                NaN                NaN               NaN
# 238                NaN                NaN               NaN
#
#      Forest Area, 2020  Total Land Area, 2020  \
# 229             442.30                 1219.0
# 230           46230.90                88205.0
# 231           14643.09                31007.0
# 232               5.83                   14.0
# 233             665.07                26600.0
# 234             549.00                52797.0
# 235           44814.03                74339.0
# 236           17444.58                38685.0
# 237                NaN                    NaN
# 238                NaN                    NaN
#
#      Forest Area as a Proportion of Total Land Area, 2020  \
# 229                                              36.28
# 230                                              52.41
# 231                                              47.23
# 232                                              41.64
# 233                                               2.50
# 234                                               1.04
# 235                                              60.28
# 236                                              45.09
# 237                                                NaN
# 238                                                NaN
#
#     Deforestation, 2015-2020 Total Forest Area Affected by Fire, 2015
# 229                      ...                                      ...
# 230                   108.29                                      ...
# 231                     1.59                                      ...
# 232                      ...                                      ...
# 233                      ...                                      ...
# 234                      ...                                      ...
# 235                   189.71                                    15077
# 236                    46.07                                     2830
# 237                      NaN                                      NaN
# 238                      NaN                                      NaN

# %% [markdown]
# ## Data Cleaning & Data Handling

# %%
import numpy as np
# Replace "..." with NaN to recognize them as missing values
df.replace('...',np.nan,inplace=True)

# Now, print the number of missing values in each column after replacement
print()

# Remove rows with missing (NaN) values from the DataFrame
df = df.dropna()
df.head()
# Out:
#     CountryID Country and Area  Forest Area, 1990  Forest Area, 2000  \
# 9        32.0        Argentina           35204.00           33378.00
# 13       40.0          Austria            3775.67            3838.14
# 16       48.0          Bahrain               0.22               0.37
# 19      112.0          Belarus            7780.00            8273.00
# 20       56.0          Belgium             677.40             667.30
#
#     Forest Area, 2010 Forest Area, 2015  Forest Area, 2020  \
# 9            30214.00             29097           28573.00
# 13            3863.20           3881.19            3899.15
# 16               0.52               0.6               0.70
# 19            8630.00            8633.5            8767.60
# 20             689.87             689.3             689.30
#
#     Total Land Area, 2020  \
# 9                273669.0
# 13                 8252.0
# 16                   77.0
# 19                20297.8
# 20                 3028.0
#
#     Forest Area as a Proportion of Total Land Area, 2020  \
# 9                                               10.44
# 13                                              47.25
# 16                                               0.91
# 19                                              43.19
# 20                                              22.76
#
#    Deforestation, 2015-2020 Total Forest Area Affected by Fire, 2015
# 9                     134.8                                      128
# 13                     5.81                                     0.09
# 16                        0                                        0
# 19                      3.5                                    13.89
# 20                      1.5                                        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83 entries, 9 to 236
# Data columns (total 11 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   CountryID                                             83 non-null     float64
#  1   Country and Area                                      83 non-null     object
#  2   Forest Area, 1990                                     83 non-null     float64
#  3   Forest Area, 2000                                     83 non-null     float64
#  4   Forest Area, 2010                                     83 non-null     float64
#  5   Forest Area, 2015                                     83 non-null     object
#  6   Forest Area, 2020                                     83 non-null     float64
#  7   Total Land Area, 2020                                 83 non-null     float64
#  8   Forest Area as a Proportion of Total Land Area, 2020  83 non-null     float64
#  9   Deforestation, 2015-2020                              83 non-null     object
#  10  Total Forest Area Affected by Fire, 2015              83 non-null     object
# dtypes: float64(7), object(4)
# memory usage: 7.8+ KB

# %% [markdown]
# # 4. Basic data manipulation

# %%
# Calculate the change in forest area from 1990 to 2020 and store it in a new column
df['Forest_Change_1990_2020'] =  df['Forest Area, 2020']-df['Forest Area, 1990']

avg_change =  np.mean(df['Forest_Change_1990_2020'].values)
print(f"Average forest area change between 1990 and 2020: {avg_change:.2f} thousand hectares")  # Print the average change
# Out:
# Average forest area change between 1990 and 2020: -762.83 thousand hectares
# <ipython-input-13-bb8ef97d1936>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Forest_Change_1990_2020'] =  df['Forest Area, 2020']-df['Forest Area, 1990']

# %%
df[df['Country and Area']=='WORLD']
# Out:
# Empty DataFrame
# Columns: [CountryID, Country and Area, Forest Area, 1990, Forest Area, 2000, Forest Area, 2010, Forest Area, 2015, Forest Area, 2020, Total Land Area, 2020, Forest Area as a Proportion of Total Land Area, 2020, Deforestation, 2015-2020, Total Forest Area Affected by Fire, 2015, Forest_Change_1990_2020]
# Index: []

# %% [markdown]
# # 5. Data visualization

# %%
# 'WORLD'?
countries_only = df[df['Country and Area'] != 'WORLD']

# Now select the top 10 countries with the largest forest area in 2020
top_10= df.nlargest(10,'Forest Area, 2020')

# %%
top_10.head(10)
# Out:
#      CountryID                  Country and Area  Forest Area, 1990  \
# 174      643.0                Russian Federation          808949.90
# 29        76.0                            Brazil          588898.00
# 38       124.0                            Canada          348272.93
# 43       156.0                             China          157140.59
# 163      604.0                              Peru           76448.54
# 97       356.0                             India           63938.00
# 134      484.0                            Mexico           70591.65
# 25        68.0  Bolivia (Plurinational State of)           57804.72
# 224      834.0       United Republic of Tanzania           57390.01
# 235      894.0                            Zambia           47412.00
#
#      Forest Area, 2000  Forest Area, 2010 Forest Area, 2015  \
# 174          809268.50          815135.60         814930.46
# 29           551088.60          511580.70          503884.8
# 38           347801.97          347322.21         347115.71
# 43           177000.55          200610.38         210294.25
# 163           75297.83           74049.80          73194.53
# 97            67591.00           69496.00             70828
# 134           68381.35           66943.31          66330.91
# 25            55101.39           53086.01          52027.22
# 224           53670.01           49950.01             48090
# 235           47054.00           46696.00           45755.1
#
#      Forest Area, 2020  Total Land Area, 2020  \
# 174          815311.60              1637687.0
# 29           496619.60               835814.0
# 38           346928.10               909351.0
# 43           219978.18               942470.0
# 163           72330.37               128000.0
# 97            72160.00               297319.0
# 134           65692.08               194395.0
# 25            50833.76               108330.0
# 224           45745.00                88580.0
# 235           44814.03                74339.0
#
#      Forest Area as a Proportion of Total Land Area, 2020  \
# 174                                              49.78
# 29                                               59.42
# 38                                               38.15
# 43                                               23.34
# 163                                              56.51
# 97                                               24.27
# 134                                              33.79
# 25                                               46.92
# 224                                              51.64
# 235                                              60.28
#
#     Deforestation, 2015-2020 Total Forest Area Affected by Fire, 2015  \
# 174                        0                                   2748.9
# 29                    1695.7                                 32998.07
# 38                     37.52                                  3861.65
# 43                     133.2                                    12.94
# 163                   179.09                                    22.41
# 97                     668.4                                     3577
# 134                   165.82                                    59.14
# 25                    242.54                                   255.87
# 224                      474                                    587.3
# 235                   189.71                                    15077
#
#      Forest_Change_1990_2020
# 174                  6361.70
# 29                 -92278.40
# 38                  -1344.83
# 43                  62837.59
# 163                 -4118.17
# 97                   8222.00
# 134                 -4899.57
# 25                  -6970.96
# 224                -11645.01
# 235                 -2597.97

# %%
# Set the figure size for the plot
plt.figure() # 12, width - 6, height of the figure

# Create a bar plot showing the top 10 countries by forest area in 2020
plt.bar(top_10['Country and Area'],top_10['Forest Area, 2020'])
plt.title('Comparing top 10 forest area for 2020')  # Set the title of the plot
plt.xlabel('Country and Area')  # Label the x-axis as 'Country'
plt.ylabel('Area')  # Label the y-axis as 'Forest Area'

plt.xticks(rotation=45, ha='right')  # Rotate the x-axis labels for better readability
plt.tight_layout()  # Adjust the layout to make sure everything fits without overlapping

plt.show()  # Display the plot

# %% [markdown]
# # 6. Prediction analysis

# %%
countries = df['Country and Area'].values

# %%
def graphing_plot(country):
  country_data = df[df['Country and Area']==country]  # Filter the DataFrame for data related to your country

  # Define the years of interest
  years = [1990,2000,2010,2020]  # You can add more years
  forest_areas = country_data[['Forest Area, 1990', 'Forest Area, 2000', 'Forest Area, 2010', 'Forest Area, 2020']].values.flatten()  # Extract forest area data for the specified years

  # Reshape the years data to fit the model
  X = np.array(years).reshape(-1,1)
  y = forest_areas

  # Create an instance of the LinearRegression model
  model = LinearRegression()  # Initialize the model
  model.fit(X, y)  # Fit the model with the data

  # Predict the forest area for the year 2030
  prediction_2030 = model.predict([[2030]])  # Make sure the input format matches the training data

  # Set the figure size for the plot
  plt.figure(figsize=(10,6))  # Adjust the size for better visibility
  plt.scatter(years, forest_areas,color='blue',label='Actual Data')  # Plot the actual data as a scatter plot
  plt.plot(years, model.predict(X),color='red',label='Linear Regrssion')  # Plot the linear regression line
  plt.scatter([2030],prediction_2030 , color='green',label='2030 Prediction')  # Plot the prediction for 2030 as a scatter point

  plt.title(f'Forest Area Prediction for {country}')  # Set the title of the plot
  plt.xlabel('year')  # Label the x-axis as 'Year'
  plt.ylabel('Forest area')  # Label the y-axis as 'Forest Area (1000 ha)'
  plt.legend()  # Display the legend
  plt.grid(True)  # Enable the grid for better readability
  plt.show()  # Display the plot

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))


countries = ['Turkey','Spain','Nigeria','Mauritania']
# Plotting on each subplot
for i, ax in enumerate(axes.flat):
  graphing_plot(countries[i])

# %%
# Select a country for the prediction analysis
# country = []'Nigeria'  # You can change this to any other country present in your dataset
for country in countries:
  country_data = df[df['Country and Area']==country]  # Filter the DataFrame for data related to your country

  # Define the years of interest
  years = [1990,2000,2010,2020]  # You can add more years
  forest_areas = country_data[['Forest Area, 1990', 'Forest Area, 2000', 'Forest Area, 2010', 'Forest Area, 2020']].values.flatten()  # Extract forest area data for the specified years

  # Set the figure size for the plot
  plt.figure()  # Adjust the size for better visibility
  plt.scatter(years, forest_areas, color='blue',label='Actual Data')  # Plot the actual forest area data as a scatter plot
  plt.xlabel('Year')  # Label the x-axis as 'Year'
  plt.ylabel('Forest Area')  # Label the y-axis as 'Forest Area'
  plt.title(f'Forest Area in {country} Over Time')  # Set the title of the plot
  plt.legend()  # Display the legend
  plt.grid(True)  # Enable the grid for better readability
  plt.show()  # Display the plot

  # Reshape the years data to fit the model
  X = np.array(years).reshape(-1,1)
  y = forest_areas

  # Create an instance of the LinearRegression model
  model = LinearRegression()  # Initialize the model
  model.fit(X, y)  # Fit the model with the data

  # Predict the forest area for the year 2030
  prediction_2030 = model.predict([[2030]])  # Make sure the input format matches the training data

  # Set the figure size for the plot
  plt.figure(figsize=(10,6))  # Adjust the size for better visibility
  plt.scatter(years, forest_areas,color='blue',label='Actual Data')  # Plot the actual data as a scatter plot
  plt.plot(years, model.predict(X),color='red',label='Linear Regrssion')  # Plot the linear regression line
  plt.scatter([2030],prediction_2030 , color='green',label='2030 Prediction')  # Plot the prediction for 2030 as a scatter point

  plt.title(f'Forest Area Prediction for {country}')  # Set the title of the plot
  plt.xlabel('year')  # Label the x-axis as 'Year'
  plt.ylabel('Forest area')  # Label the y-axis as 'Forest Area (1000 ha)'
  plt.legend()  # Display the legend
  plt.grid(True)  # Enable the grid for better readability
  plt.show()  # Display the plot

  # Print the predicted forest area for your country in 2030
  print(f"Predicted forest area for {country} in 2030: {prediction_2030[0]:.2f} thousand hectares")  # Format the output for clarity
  # Print the rate of change per year according to the model
  print(f"Rate of change: {model.coef_[0]:.2f} thousand hectares per year")  # Shows the slope of the linear regression line
# Out:
# Predicted forest area for Turkey in 2030: 22870.16 thousand hectares
# Rate of change: 82.45 thousand hectares per year
# Predicted forest area for Spain in 2030: 20892.51 thousand hectares
# Rate of change: 154.54 thousand hectares per year
# Predicted forest area for Nigeria in 2030: 19993.90 thousand hectares
# Rate of change: -163.30 thousand hectares per year
# Predicted forest area for Mauritania in 2030: 258.40 thousand hectares
# Rate of change: -5.44 thousand hectares per year
